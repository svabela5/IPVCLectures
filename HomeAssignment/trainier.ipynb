# %%
from ultralytics import YOLO

# %%
model = YOLO('yolo11n.pt')

# %%
results = model.train(
    data='data.yaml',       # Path to your custom dataset configuration file
    epochs=50,              # Number of epochs to train for (adjust as needed)
    imgsz=640,              # Input image size (default is 640)
    batch=16,               # Batch size (adjust lower if you run out of GPU memory)
    name='AI Detector',  # Name of the run, results will be saved to runs/detect/yolov8n_custom
    project='AI Models'
)
# Out:
# Ultralytics 8.3.241  Python-3.11.14 torch-2.5.1 CUDA:0 (NVIDIA GeForce RTX 3060 Laptop GPU, 6144MiB)
# ...

# %%
from ultralytics import YOLO
import numpy as np

# %%
model = YOLO('yolo11n.pt')

# %%
results = model.train(
    data='latestdata_TEST.yaml',
    epochs=100,
    imgsz=640,
    batch=16,
    name='AI Detector 060126',
    patience=10,
    project='AI Models'
)
# Out:
# New https://pypi.org/project/ultralytics/8.4.7 available  Update with 'pip install -U ultralytics'
# Ultralytics 8.3.241  Python-3.11.14 torch-2.5.1 CUDA:0 (NVIDIA GeForce RTX 3060 Laptop GPU, 6144MiB)
# ...

# %%
model = YOLO('AI Models/AI Detector 0601262/weights/best.pt')
print("--- STARTING DIAGNOSTIC RUN ---")
metrics = model.val(data='latestdata_TEST.yaml', split='val')

print("\n--- DIAGNOSTIC RESULTS ---")
print(f"Mean Precision: {metrics.box.mp:.4f}")
print(f"Mean Recall: {metrics.box.mr:.4f}")
print(f"mAP@50: {metrics.box.map50:.4f}")
print(f"mAP@50-95: {metrics.box.map:.4f}")

# CHECK 4: Manual F1 Calculation (Fallback)
mp, mr, map50, map95 = metrics.box.mean_results()
if (mp + mr) > 0:
    f1 = 2 * (mp * mr) / (mp + mr)
    print(f"Calculated F1 Score: {f1:.4f}")
else:
    print("Calculated F1 Score: 0.0 (Model has 0 Precision or 0 Recall)")
# Out:
# --- STARTING DIAGNOSTIC RUN ---
# Ultralytics 8.3.241  Python-3.11.14 torch-2.5.1 CUDA:0 (NVIDIA GeForce RTX 3060 Laptop GPU, 6144MiB)
# YOLO11n summary (fused): 100 layers, 2,582,737 parameters, 0 gradients, 6.3 GFLOPs
# val: Fast image access  (ping: 0.10.0 ms, read: 572.371.1 MB/s, size: 82.2 KB)
# val: Scanning C:\Users\svena\Documents\LEVEL 6\LVL 6.3\ComputerVision\HomeAssignment\Dataset\TestDataset060126\NoOcclusionDataset\labels\test.cache... 7100 images, 50 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 7100/7100  0.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 444/444 10.5it/s 42.2s0.2ss
#                    all       7100       7050      0.795      0.783      0.866      0.797
#                ChatGPT       2325       2325      0.934      0.654      0.898      0.826
#                 Claude       2325       2325      0.725      0.807      0.841      0.785
# ...
